# %% [markdown]
# # Code Written by:
# **Shweta Tiwari**
# *20 Oct 2023*

# %% [markdown]
# ## Algorithm:  Linearithmic Multiplication

# %%
import time

# %%
import numpy as np

# %% [markdown]
# # Algorithm

# %%
# %%time
def mult(x, y):
    nx, ny = len(x), len(y)

    # auxiliary x
    fx = np.zeros(nx + ny, dtype=np.float64)
    fx[:nx] = list(map(int, reversed(x)))

    # auxiliary y
    fy = np.zeros(nx + ny, np.float64)
    fy[:ny] += list(map(int, reversed(y)))

    # convolution via FFT
    fx = np.fft.fft(fx)
    fy = np.fft.fft(fy)
    z = np.fft.ifft(fx * fy).real.round().astype(int)

    # carry over
    for i in range(nx + ny - 1):
        z[i + 1] += z[i] // 10
        z[i] %= 10

    return ''.join(map(str, reversed(z)))
# Out:
# CPU times: user 0 ns, sys: 4 µs, total: 4 µs
# Wall time: 6.2 µs

# %% [markdown]
# # Run

# %%
# %%time
for _ in range(10):
    x, y = np.random.randint(1e+3, 1e+10, 2)
    print(x, '*', y, '=', mult(str(x), str(y)))
# Out:
# 8397189619 * 4586325149 = 38512241930541428231
# 6015924050 * 6199272428 = 37294352092107093400
# 3319096703 * 8952515380 = 29714264281314792140
# 8595952000 * 6524193933 = 56081657886759216000
# 4828774171 * 2569587909 = 12407959725093098439
# 481165220 * 2375728714 = 1143118029332127080
# 2676464168 * 9019930710 = 24141521343157799280
# 3877553953 * 9667008322 = 37484346332654996866
# 4229466535 * 3348922788 = 14164156860144899580
# 6974337356 * 6656081990 = 46421761267455818440
# CPU times: user 13 ms, sys: 34 µs, total: 13.1 ms
# Wall time: 16.2 ms

# %% [markdown]
# # The End
