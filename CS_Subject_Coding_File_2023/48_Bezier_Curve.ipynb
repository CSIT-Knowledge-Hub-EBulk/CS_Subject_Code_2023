# %% [markdown]
# # Code Written by:
# **Shweta Tiwari**
# *20 Oct 2023*

# %% [markdown]
# ## Algorithm:  Bezier Curve

# %%
import time

# %%
import numpy as np
import scipy.special
from bokeh.plotting import figure, show, output_notebook

# %% [markdown]
# # Algorithm

# %%
# %%time
def bezier(points, steps=100):
    n = len(points)
    b = [scipy.special.binom(n - 1, i) for i in range(n)]
    r = np.arange(n)

    for t in np.linspace(0, 1, steps):
        u = np.power(t, r) * np.power(1 - t, n - r - 1) * b
        yield t, u @ points
# Out:
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 6.44 µs

# %% [markdown]
# # Run

# %% [markdown]
# ## Plot

# %%
# %%time
output_notebook()
# Out:
# CPU times: user 50 µs, sys: 11 µs, total: 61 µs
# Wall time: 63.2 µs

# %%
# %%time
points = np.array([[0, 0], [0, 1], [1, 1], [1, 0]] * 4)
plot = figure()

for i in range(3, 14):
    curve = np.array([p for _, p in bezier(points[:i])])
    color = tuple(np.random.randint(0, 256, 3))
    plot.line(curve[:, 0], curve[:, 1], color=color)

show(plot)
# Out:
#   <div id="bbea3e19-20ad-417b-b508-caaca39fafdb" data-root-id="p1001" style="display: contents;"></div>
# CPU times: user 515 ms, sys: 39 ms, total: 554 ms
# Wall time: 563 ms

# %% [markdown]
# # The End
