# %% [markdown]
# # Code Written by:
# **Shweta Tiwari**
# *20 Oct 2023*

# %% [markdown]
# ## Algorithm:  Bulls and Cows

# %%
import time

# %%
from random import choice, sample
from itertools import permutations

# %% [markdown]
# # Algorithm

# %% [markdown]
# ## Common

# %%
# %%time
def score(x, y):
    bulls = sum(i == j for i, j in zip(x, y))
    cows = len(set(x) & set(y)) - bulls
    return bulls, cows
# Out:
# CPU times: user 7 µs, sys: 0 ns, total: 7 µs
# Wall time: 11.7 µs

# %% [markdown]
# ## Player 1

# %%
# %%time
def player1(player2):
    secret = sample(range(10), 4)

    tip = next(player2)
    while True:
        b, c = score(secret, tip)
        if b < 4:
            print(b, 'bulls', c, 'cows')
            tip = player2.send((b, c))
        else:
            print('you won')
            break
# Out:
# CPU times: user 16 µs, sys: 0 ns, total: 16 µs
# Wall time: 22.6 µs

# %% [markdown]
# ## Player 2

# %%
# %%time
def player2():
    tips = list(permutations(range(10), 4))

    while True:
        tip = choice(tips)
        print(tip, '?')
        bc = yield tip
        tips = [i for i in tips if score(i, tip) == bc]
# Out:
# CPU times: user 6 µs, sys: 1 µs, total: 7 µs
# Wall time: 13.4 µs

# %% [markdown]
# # Run

# %% [markdown]
# ## Game

# %%
# %%time
player1(player2())
# Out:
# (4, 1, 3, 5) ?
# 0 bulls 2 cows
# (3, 5, 0, 9) ?
# 0 bulls 0 cows
# (7, 6, 1, 4) ?
# 2 bulls 2 cows
# (7, 4, 1, 6) ?
# 0 bulls 4 cows
# (1, 6, 7, 4) ?
# you won
# CPU times: user 25.4 ms, sys: 1.67 ms, total: 27.1 ms
# Wall time: 33.6 ms

# %%
# %%time
player1(player2())
# Out:
# (4, 8, 1, 5) ?
# 0 bulls 3 cows
# (5, 3, 8, 1) ?
# 0 bulls 3 cows
# (1, 0, 5, 8) ?
# 3 bulls 0 cows
# (1, 9, 5, 8) ?
# you won
# CPU times: user 22.7 ms, sys: 1.15 ms, total: 23.8 ms
# Wall time: 28 ms

# %% [markdown]
# # The End
