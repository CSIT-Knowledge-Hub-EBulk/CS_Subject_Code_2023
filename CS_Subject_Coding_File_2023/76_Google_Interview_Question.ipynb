# %% [markdown]
# # Code Written by:
# **Shweta Tiwari**
# *20 Oct 2023*

# %% [markdown]
# ## Algorithm: Google Interview Question

# %%
import time

# %%
import numpy as np

# %% [markdown]
# # Algorithm

# %%
# %%time
def solve_question(trials):
    # range to search in
    probability_range = np.array([0., 1.])

    while True:
        # prob. to see car in 10 minutes
        probability_10min = probability_range.mean()

        # simulate three 10-minute intervals
        events = np.random.rand(trials, 3) < probability_10min
        events = np.sum(events, axis=1) > 0

        # prob. to see car in 30 minutes
        probability_30min = np.mean(events)
        if abs(probability_30min - .95) < 1e-4:
            return probability_10min

        # bisection
        i = 0 if probability_30min < .95 else 1
        probability_range[i] = probability_10min
# Out:
# CPU times: user 4 µs, sys: 0 ns, total: 4 µs
# Wall time: 7.87 µs

# %% [markdown]
# # Run

# %%
# %%time
solve_question(10**6)
# Out:
# CPU times: user 2.75 s, sys: 23.1 ms, total: 2.78 s
# Wall time: 2.85 s
# 0.6308593740686774

# %%
# %%time
solve_question(10**6)
# Out:
# CPU times: user 534 ms, sys: 946 µs, total: 534 ms
# Wall time: 535 ms
# 0.6318359375

# %%
# %%time
solve_question(10**6)
# Out:
# CPU times: user 1.12 s, sys: 10 µs, total: 1.12 s
# Wall time: 1.12 s
# 0.6317124366760254

# %%
# %%time
1 - pow(0.05, 1/3)
# Out:
# CPU times: user 7 µs, sys: 0 ns, total: 7 µs
# Wall time: 10.5 µs
# 0.6315968501359612

# %% [markdown]
# # The End
