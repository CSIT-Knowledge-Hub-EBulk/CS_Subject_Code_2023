# %% [markdown]
# # Code Written by:
# **Shweta Tiwari**
# *20 Oct 2023*

# %% [markdown]
# ## Algorithm:  Hanoi Tower II

# %%
import time

# %% [markdown]
# # Algorithm

# %%
# %%time
def get_rods(move, towers, left, middle, right):
    if towers:
        if (move << 1) & (1 << towers):
            right.append(towers)
            get_rods(move, towers - 1, middle, left, right)
        else:
            left.append(towers)
            get_rods(move, towers - 1, left, right, middle)
# Out:
# CPU times: user 4 µs, sys: 1 µs, total: 5 µs
# Wall time: 9.06 µs

# %%
# %%time
def get_move(towers, left, middle, right):
    if not towers:
        return 0
    if not left or right and left[0] < right[0]:
        move = 1 << (towers - 1)
        return move + get_move(towers - 1, middle, left, right[1:])
    else:
        return get_move(towers - 1, left[1:], right, middle)
# Out:
# CPU times: user 7 µs, sys: 0 ns, total: 7 µs
# Wall time: 11.2 µs

# %%
# %%time
def hanoi(towers):
    for i in range(2 ** towers):
        rods = [], [], []
        get_rods(i, towers, *rods)
        move = get_move(towers, *rods)
        print('{:2} moves -- {} {} {}'.format(move, *rods))
# Out:
# CPU times: user 5 µs, sys: 0 ns, total: 5 µs
# Wall time: 8.82 µs

# %% [markdown]
# # Run

# %%
# %%time
hanoi(2)
# Out:
#  0 moves -- [2, 1] [] []
#  1 moves -- [2] [1] []
#  2 moves -- [] [1] [2]
#  3 moves -- [] [] [2, 1]
# CPU times: user 2.11 ms, sys: 227 µs, total: 2.33 ms
# Wall time: 2.84 ms

# %%
# %%time
hanoi(3)
# Out:
#  0 moves -- [3, 2, 1] [] []
#  1 moves -- [3, 2] [] [1]
#  2 moves -- [3] [2] [1]
#  3 moves -- [3] [2, 1] []
#  4 moves -- [] [2, 1] [3]
#  5 moves -- [1] [2] [3]
#  6 moves -- [1] [] [3, 2]
#  7 moves -- [] [] [3, 2, 1]
# CPU times: user 1.48 ms, sys: 96 µs, total: 1.58 ms
# Wall time: 1.59 ms

# %%
# %%time
hanoi(4)
# Out:
#  0 moves -- [4, 3, 2, 1] [] []
#  1 moves -- [4, 3, 2] [1] []
#  2 moves -- [4, 3] [1] [2]
#  3 moves -- [4, 3] [] [2, 1]
#  4 moves -- [4] [3] [2, 1]
#  5 moves -- [4, 1] [3] [2]
#  6 moves -- [4, 1] [3, 2] []
#  7 moves -- [4] [3, 2, 1] []
#  8 moves -- [] [3, 2, 1] [4]
#  9 moves -- [] [3, 2] [4, 1]
# 10 moves -- [2] [3] [4, 1]
# 11 moves -- [2, 1] [3] [4]
# 12 moves -- [2, 1] [] [4, 3]
# 13 moves -- [2] [1] [4, 3]
# 14 moves -- [] [1] [4, 3, 2]
# 15 moves -- [] [] [4, 3, 2, 1]
# CPU times: user 469 µs, sys: 0 ns, total: 469 µs
# Wall time: 474 µs

# %%
# %%time
hanoi(5)
# Out:
#  0 moves -- [5, 4, 3, 2, 1] [] []
#  1 moves -- [5, 4, 3, 2] [] [1]
#  2 moves -- [5, 4, 3] [2] [1]
#  3 moves -- [5, 4, 3] [2, 1] []
#  4 moves -- [5, 4] [2, 1] [3]
#  5 moves -- [5, 4, 1] [2] [3]
#  6 moves -- [5, 4, 1] [] [3, 2]
#  7 moves -- [5, 4] [] [3, 2, 1]
#  8 moves -- [5] [4] [3, 2, 1]
#  9 moves -- [5] [4, 1] [3, 2]
# 10 moves -- [5, 2] [4, 1] [3]
# 11 moves -- [5, 2, 1] [4] [3]
# 12 moves -- [5, 2, 1] [4, 3] []
# 13 moves -- [5, 2] [4, 3] [1]
# 14 moves -- [5] [4, 3, 2] [1]
# 15 moves -- [5] [4, 3, 2, 1] []
# 16 moves -- [] [4, 3, 2, 1] [5]
# 17 moves -- [1] [4, 3, 2] [5]
# 18 moves -- [1] [4, 3] [5, 2]
# 19 moves -- [] [4, 3] [5, 2, 1]
# 20 moves -- [3] [4] [5, 2, 1]
# 21 moves -- [3] [4, 1] [5, 2]
# 22 moves -- [3, 2] [4, 1] [5]
# 23 moves -- [3, 2, 1] [4] [5]
# 24 moves -- [3, 2, 1] [] [5, 4]
# 25 moves -- [3, 2] [] [5, 4, 1]
# 26 moves -- [3] [2] [5, 4, 1]
# 27 moves -- [3] [2, 1] [5, 4]
# 28 moves -- [] [2, 1] [5, 4, 3]
# 29 moves -- [1] [2] [5, 4, 3]
# 30 moves -- [1] [] [5, 4, 3, 2]
# 31 moves -- [] [] [5, 4, 3, 2, 1]
# CPU times: user 359 µs, sys: 550 µs, total: 909 µs
# Wall time: 1.34 ms

# %% [markdown]
# # The End
