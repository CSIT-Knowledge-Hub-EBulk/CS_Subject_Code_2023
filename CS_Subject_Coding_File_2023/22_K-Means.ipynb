# %% [markdown]
# # Code Written by:
# **Shweta Tiwari**
# *20 Oct 2023*

# %% [markdown]
# ## Algorithm:  K-Means

# %%
import time

# %%
import numpy as np
from bokeh.plotting import figure, gridplot, show, output_notebook

# %%
# !pip install --upgrade bokeh==2.4.3
# Out:
# Requirement already satisfied: bokeh==2.4.3 in /usr/local/lib/python3.10/dist-packages (2.4.3)
# Requirement already satisfied: Jinja2>=2.9 in /usr/local/lib/python3.10/dist-packages (from bokeh==2.4.3) (3.1.2)
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.10/dist-packages (from bokeh==2.4.3) (1.23.5)
# Requirement already satisfied: packaging>=16.8 in /usr/local/lib/python3.10/dist-packages (from bokeh==2.4.3) (23.2)
# Requirement already satisfied: pillow>=7.1.0 in /usr/local/lib/python3.10/dist-packages (from bokeh==2.4.3) (9.4.0)
# Requirement already satisfied: PyYAML>=3.10 in /usr/local/lib/python3.10/dist-packages (from bokeh==2.4.3) (6.0.1)
# Requirement already satisfied: tornado>=5.1 in /usr/local/lib/python3.10/dist-packages (from bokeh==2.4.3) (6.3.2)
# Requirement already satisfied: typing-extensions>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from bokeh==2.4.3) (4.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from Jinja2>=2.9->bokeh==2.4.3) (2.1.3)

# %% [markdown]
# # Algorithm

# %%
# %%time
def kmeans(points, n_clusters):
    # sample initial centroids
    sample = np.random.choice(len(points), n_clusters, replace=False)
    centroid = points[sample]

    loss = [-1, -2]
    while not np.allclose(*loss):
        # compute distance for each pair: point/centroid
        distance = [np.sqrt(((points - c) ** 2).sum(1)) for c in centroid]
        # new loss
        loss = loss[1:] + [np.sum(distance)]
        # assign new clusters
        cluster = np.argmin(distance, axis=0)
        # update centroids by new cluster means
        for i in range(n_clusters):
            centroid[i] = np.mean(points[cluster == i], axis=0)

    return cluster
# Out:
# CPU times: user 7 µs, sys: 0 ns, total: 7 µs
# Wall time: 22.6 µs

# %% [markdown]
# # Run

# %% [markdown]
# *generate clusters*

# %%
# %%time
n = 100
A = np.random.multivariate_normal([2, 0], [[1, .1], [-4, 1]], n)
B = np.random.multivariate_normal([-2, 0], [[1, -4], [.1, 1]], n)
C = np.random.multivariate_normal([2, -2], [[1, 4], [-.1, 1]], n)
D = ['red', 'green', 'blue']

points = np.r_[A, B, C]
original_color = np.repeat(D[:3], n)
# Out:
# CPU times: user 1.86 ms, sys: 988 µs, total: 2.85 ms
# Wall time: 2.86 ms
# <timed exec>:2: RuntimeWarning: covariance is not positive-semidefinite.
# <timed exec>:3: RuntimeWarning: covariance is not positive-semidefinite.
# <timed exec>:4: RuntimeWarning: covariance is not positive-semidefinite.

# %% [markdown]
# *detect k-means clusters*

# %%
# %%time
cluster = kmeans(points, 3)
new_color = [D[i] for i in cluster]
# Out:
# CPU times: user 5.22 ms, sys: 0 ns, total: 5.22 ms
# Wall time: 5.24 ms

# %% [markdown]
# *plot original and new clusters*

# %%
# %%time
output_notebook()

plot1 = figure(title='original clusters', plot_height=300)
plot1.scatter(x=points[:, 0], y=points[:, 1], color=original_color)

plot2 = figure(title='k-means clusters', plot_height=300)
plot2.scatter(x=points[:, 0], y=points[:, 1], color=new_color)

show(gridplot([[plot1], [plot2]]))
# Out:
#   <div class="bk-root" id="b19ab094-c57c-4a41-9561-a8435e56b738" data-root-id="1105"></div>
# CPU times: user 116 ms, sys: 2.96 ms, total: 119 ms
# Wall time: 121 ms

# %% [markdown]
# # The End
