# %% [markdown]
# # Code Written by:
# **Shweta Tiwari**
# *20 Oct 2023*

# %% [markdown]
# ## Algorithm:  String Searching

# %%
import time

# %% [markdown]
# # Algorithm

# %%
# %%time
def search(text, pattern):
    i, k = 0, len(pattern)
    table = {c: k - i for i, c in enumerate(pattern)}

    while True:
        print(f'search @ {i}')
        if text[i:i + k] == pattern:
            print(f'FOUND @ {i}')
        if i + k < len(text):
            i += table.get(text[i + k], k + 1)
        else:
            break
# Out:
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 9.3 µs

# %% [markdown]
# # Run

# %%
# %%time
text = 'A parabolic (or paraboloid or paraboloidal) reflector (or dish or mirror)'
len(text)
# Out:
# CPU times: user 28 µs, sys: 0 ns, total: 28 µs
# Wall time: 31.7 µs
# 73

# %%
# %%time
search(text, 'reflector')
# Out:
# search @ 0
# search @ 10
# search @ 20
# search @ 30
# search @ 40
# search @ 44
# FOUND @ 44
# search @ 54
# search @ 56
# search @ 66
# CPU times: user 2.5 ms, sys: 897 µs, total: 3.39 ms
# Wall time: 3.66 ms

# %%
# %%time
search(text, 'not to be found')
# Out:
# search @ 0
# search @ 6
# search @ 10
# search @ 11
# search @ 17
# search @ 33
# search @ 40
# search @ 44
# search @ 60
# CPU times: user 216 µs, sys: 32 µs, total: 248 µs
# Wall time: 284 µs

# %% [markdown]
# # The End
