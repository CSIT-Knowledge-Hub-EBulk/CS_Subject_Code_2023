# %% [markdown]
# # Code Written by:
# **Shweta Tiwari**
# *20 Oct 2023*

# %% [markdown]
# ## Algorithm:  Union-Find

# %%
import time

# %% [markdown]
# # Algorithm

# %%
# %%time
def find(data, i):
    if i != data[i]:
        data[i] = find(data, data[i])
    return data[i]
# Out:
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 5.96 µs

# %%
# %%time
def union(data, i, j):
    pi, pj = find(data, i), find(data, j)
    if pi != pj:
        data[pi] = pj
# Out:
# CPU times: user 5 µs, sys: 2 µs, total: 7 µs
# Wall time: 9.54 µs

# %%
# %%time
def connected(data, i, j):
    return find(data, i) == find(data, j)
# Out:
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 6.91 µs

# %% [markdown]
# # Run

# %%
# %%time
n = 10
data = [i for i in range(n)]
connections = [(0, 1), (1, 2), (0, 9), (5, 6), (6, 4), (5, 9)]

# union
for i, j in connections:
    union(data, i, j)

# find
for i in range(n):
    print('item', i, '-> component', find(data, i))
# Out:
# item 0 -> component 9
# item 1 -> component 9
# item 2 -> component 9
# item 3 -> component 3
# item 4 -> component 9
# item 5 -> component 9
# item 6 -> component 9
# item 7 -> component 7
# item 8 -> component 8
# item 9 -> component 9
# CPU times: user 1 ms, sys: 41 µs, total: 1.04 ms
# Wall time: 900 µs

# %% [markdown]
# # The End
