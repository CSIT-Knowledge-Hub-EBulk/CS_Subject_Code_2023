# %% [markdown]
# # Code Written by:
# **Shweta Tiwari**
# *20 Oct 2023*

# %% [markdown]
# ## Algorithm:  4Sum

# %%
import time

# %%
import numpy as np
from itertools import combinations, product
from collections import defaultdict

# %% [markdown]
# # Algorithm

# %%
# %%time
def sum4(data):
    # store 2-sums
    sum_of_2 = defaultdict(list)
    for i, j in combinations(range(len(data)), 2):
        k = data[i] + data[j]
        sum_of_2[k].append((i, j))

    # match pairs of 2-sums
    sum_of_4 = set()
    for k in sum_of_2:
        if k >= 0 and -k in sum_of_2:
            for i, j in product(sum_of_2[k], sum_of_2[-k]):
                index = tuple(sorted(set(i + j)))
                if len(index) == 4:
                    sum_of_4.add(index)

    return sum_of_4
# Out:
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 5.96 µs

# %% [markdown]
# # Run

# %%
# %%time
n = 10
data = np.random.randint(-n, n, n)
data
# Out:
# CPU times: user 223 µs, sys: 48 µs, total: 271 µs
# Wall time: 3.63 ms
# array([ -6,   2, -10,   0,   2,   0,   5,  -3,   8,  -9])

# %%
# %%time
for index in sum4(data):
    print(index, data[list(index)])
# Out:
# (2, 6, 7, 8) [-10   5  -3   8]
# (1, 2, 5, 8) [  2 -10   0   8]
# (1, 2, 3, 8) [  2 -10   0   8]
# (2, 4, 5, 8) [-10   2   0   8]
# (2, 3, 4, 8) [-10   0   2   8]
# (1, 4, 6, 9) [ 2  2  5 -9]
# CPU times: user 6.11 ms, sys: 0 ns, total: 6.11 ms
# Wall time: 7.4 ms

# %% [markdown]
# # The End
