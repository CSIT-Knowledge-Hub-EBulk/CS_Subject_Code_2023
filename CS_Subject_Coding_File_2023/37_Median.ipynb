# %% [markdown]
# # Code Written by:
# **Shweta Tiwari**
# *20 Oct 2023*

# %% [markdown]
# ## Algorithm:  Median

# %%
import time

# %%
import numpy as np

# %% [markdown]
# # Algorithm

# %%
# %%time
def kth(items, k, depth=1):
    if len(items) == 1:
        return items[0], depth

    # randomize on pivot
    pivot = np.random.choice(items)
    split = np.sum(items <= pivot)

    # search partition
    if k < split:
        return kth(items[items <= pivot], k, depth + 1)
    else:
        return kth(items[items > pivot], k - split, depth + 1)
# Out:
# CPU times: user 4 µs, sys: 1e+03 ns, total: 5 µs
# Wall time: 8.58 µs

# %% [markdown]
# # Run

# %%
# %%time
items = np.arange(1000000)
np.random.shuffle(items)
# Out:
# CPU times: user 60.1 ms, sys: 3.13 ms, total: 63.3 ms
# Wall time: 78.9 ms

# %%
# %%time
kth(items, len(items) // 2)
# Out:
# CPU times: user 34.1 ms, sys: 9.04 ms, total: 43.1 ms
# Wall time: 53 ms
# (500000, 23)

# %%
# %%time
kth(items, len(items) - 1)
# Out:
# CPU times: user 22.2 ms, sys: 841 µs, total: 23 ms
# Wall time: 26.7 ms
# (999999, 21)

# %% [markdown]
# # The End
